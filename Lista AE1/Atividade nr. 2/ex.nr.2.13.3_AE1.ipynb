# %% [markdown]
# # Exercise 13 (3) - Hamiltonian & Lagrangian Neural Networks

# %% [markdown]
# ### Task
# Implement and train a conventional neural network for dynamics
#
# * Implement the cost computation in the training loop
# * Perform a training with the implemented neural network and compare it to the Hamiltonian neural network (`exercise13_1.ipynb`) and the Lagrangian neural network (`exercise13_2.ipynb`)

# %%
import torch
import numpy as np
from torch.autograd import grad
import matplotlib.pyplot as plt

# %%
torch.manual_seed(2)

# %% [markdown]
# ## User settings
# sampling parameters

# %%
dx0dt = 1
k = 10
m = 1

tmaxTraining = 1.5
numberOfTrainingSamples = 50
tmaxValidation = 9
numberOfValidationSamples = 300

# %% [markdown]
# neural network architecture

# %%
neurons = 50
layers = 2

# %% [markdown]
# hyperparameters

# %%
lr = 1e-3
epochs = 5000

# %% [markdown]
# ## Utilities
# neural network

# %%
class FNN(torch.nn.Module):
    def __init__(self, inputSize, outputSize, neurons, layers):
        super().__init__()

        self.layers = layers

        self.linear1 = torch.nn.Linear(inputSize, neurons)
        self.linear2 = torch.nn.ModuleList()
        for i in range(self.layers):
            self.linear2.append(torch.nn.Linear(neurons, neurons))
        self.linear3 = torch.nn.Linear(neurons, outputSize)
        self.activation = torch.nn.Tanh()

    def forward(self, x):
        y = self.activation(self.linear1(x))
        for i in range(self.layers):
            y = self.activation(self.linear2[i](y))
        y = self.linear3(y)
        return y

# %% [markdown]
# derivative function

# %%
def getDerivative(y, x, n):
    """Compute the nth order derivative of y = f(x) with respect to x."""

    if n == 0:
        return y
    else:
        dy_dx = grad(y, x, torch.ones_like(y), create_graph=True, retain_graph=True)[0]
        return getDerivative(dy_dx, x, n - 1)

# %% [markdown]
# ## Data generation
# analytical solution

# %%
omega = np.sqrt(k / m)

A = dx0dt / omega
phi = 0
x = lambda t: A * np.sin(omega * t + phi)
dxdt = lambda t: omega * A * np.cos(omega * t + phi)
ddxdtt = lambda t: - omega ** 2 * A * np.sin(omega * t + phi)

# %% [markdown]
# training data

# %%
tTraining = np.linspace(0, tmaxTraining, numberOfTrainingSamples)
trainingData = torch.vstack((torch.from_numpy(x(tTraining)),
                             m * torch.from_numpy(dxdt(tTraining)),
                             m * torch.from_numpy(ddxdtt(tTraining)))).to(torch.float32).T

# %% [markdown]
# validation data

# %%
tValidation = np.linspace(0, tmaxValidation, numberOfValidationSamples)
validationData = torch.vstack((torch.from_numpy(x(tValidation)),
                               m * torch.from_numpy(dxdt(tValidation)),
                               m * torch.from_numpy(ddxdtt(tValidation)))).to(torch.float32).T

# %% [markdown]
# model input

# %%
modelInputTraining = trainingData[:, :2]
modelInputTraining.requires_grad = True

modelInputValidation = validationData[:, :2]
modelInputValidation.requires_grad = True

# %% [markdown]
# ## Supervised training
# pre-processing

# %%
model = FNN(2, 2, neurons, layers)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
costHistory = np.zeros(epochs)

# %% [markdown]
# training loop

# %%
for epoch in range(epochs):
    optimizer.zero_grad()

    xPred = model(modelInputTraining)

    cost = torch.mean((xPred - trainingData[:, 1:]) ** 2)
    costHistory[epoch] = cost.detach()

    cost.backward()

    optimizer.step()

    if epoch % 50 == 0:
        print("Epoch: {}/{}\t\tCost function: {:.3E}".format(epoch, epochs, cost.detach()))
# Out:
# Epoch: 0/5000		Cost function: 2.999E+00
# Epoch: 50/5000		Cost function: 7.894E-01
# Epoch: 100/5000		Cost function: 1.921E-03
# Epoch: 150/5000		Cost function: 4.565E-04
# Epoch: 200/5000		Cost function: 3.131E-04
# Epoch: 250/5000		Cost function: 2.380E-04
# Epoch: 300/5000		Cost function: 1.925E-04
# Epoch: 350/5000		Cost function: 1.616E-04
# Epoch: 400/5000		Cost function: 1.381E-04
# Epoch: 450/5000		Cost function: 1.189E-04
# Epoch: 500/5000		Cost function: 1.028E-04
# Epoch: 550/5000		Cost function: 8.898E-05
# Epoch: 600/5000		Cost function: 7.704E-05
# Epoch: 650/5000		Cost function: 6.668E-05
# Epoch: 700/5000		Cost function: 5.765E-05
# Epoch: 750/5000		Cost function: 4.979E-05
# Epoch: 800/5000		Cost function: 4.296E-05
# Epoch: 850/5000		Cost function: 3.705E-05
# Epoch: 900/5000		Cost function: 3.194E-05
# Epoch: 950/5000		Cost function: 2.755E-05
# Epoch: 1000/5000		Cost function: 2.380E-05
# Epoch: 1050/5000		Cost function: 2.059E-05
# Epoch: 1100/5000		Cost function: 1.787E-05
# Epoch: 1150/5000		Cost function: 1.556E-05
# Epoch: 1200/5000		Cost function: 1.359E-05
# Epoch: 1250/5000		Cost function: 1.191E-05
# Epoch: 1300/5000		Cost function: 1.047E-05
# Epoch: 1350/5000		Cost function: 9.227E-06
# Epoch: 1400/5000		Cost function: 8.148E-06
# Epoch: 1450/5000		Cost function: 7.203E-06
# Epoch: 1500/5000		Cost function: 6.372E-06
# Epoch: 1550/5000		Cost function: 5.636E-06
# Epoch: 1600/5000		Cost function: 4.983E-06
# Epoch: 1650/5000		Cost function: 4.402E-06
# Epoch: 1700/5000		Cost function: 1.976E-05
# Epoch: 1750/5000		Cost function: 3.588E-06
# Epoch: 1800/5000		Cost function: 3.036E-06
# Epoch: 1850/5000		Cost function: 2.676E-06
# Epoch: 1900/5000		Cost function: 2.047E-04
# Epoch: 1950/5000		Cost function: 2.266E-06
# Epoch: 2000/5000		Cost function: 1.854E-06
# Epoch: 2050/5000		Cost function: 1.638E-06
# Epoch: 2100/5000		Cost function: 2.702E-05
# Epoch: 2150/5000		Cost function: 4.703E-06
# Epoch: 2200/5000		Cost function: 1.169E-06
# Epoch: 2250/5000		Cost function: 1.049E-06
# Epoch: 2300/5000		Cost function: 9.510E-07
# Epoch: 2350/5000		Cost function: 3.687E-05
# Epoch: 2400/5000		Cost function: 9.960E-07
# Epoch: 2450/5000		Cost function: 7.381E-07
# Epoch: 2500/5000		Cost function: 6.841E-07
# Epoch: 2550/5000		Cost function: 6.399E-07
# Epoch: 2600/5000		Cost function: 3.263E-06
# Epoch: 2650/5000		Cost function: 7.554E-07
# Epoch: 2700/5000		Cost function: 5.508E-07
# Epoch: 2750/5000		Cost function: 5.270E-07
# Epoch: 2800/5000		Cost function: 5.069E-07
# Epoch: 2850/5000		Cost function: 1.006E-04
# Epoch: 2900/5000		Cost function: 6.637E-06
# Epoch: 2950/5000		Cost function: 4.955E-07
# Epoch: 3000/5000		Cost function: 4.580E-07
# Epoch: 3050/5000		Cost function: 4.471E-07
# Epoch: 3100/5000		Cost function: 4.375E-07
# Epoch: 3150/5000		Cost function: 1.103E-06
# Epoch: 3200/5000		Cost function: 7.285E-06
# Epoch: 3250/5000		Cost function: 4.859E-07
# Epoch: 3300/5000		Cost function: 4.117E-07
# Epoch: 3350/5000		Cost function: 4.048E-07
# Epoch: 3400/5000		Cost function: 3.983E-07
# Epoch: 3450/5000		Cost function: 2.948E-04
# Epoch: 3500/5000		Cost function: 3.391E-06
# Epoch: 3550/5000		Cost function: 4.082E-07
# Epoch: 3600/5000		Cost function: 3.822E-07
# Epoch: 3650/5000		Cost function: 3.760E-07
# Epoch: 3700/5000		Cost function: 3.702E-07
# Epoch: 3750/5000		Cost function: 3.646E-07
# Epoch: 3800/5000		Cost function: 3.604E-07
# Epoch: 3850/5000		Cost function: 1.766E-05
# Epoch: 3900/5000		Cost function: 4.674E-07
# Epoch: 3950/5000		Cost function: 3.517E-07
# Epoch: 4000/5000		Cost function: 3.445E-07
# Epoch: 4050/5000		Cost function: 3.392E-07
# Epoch: 4100/5000		Cost function: 3.339E-07
# Epoch: 4150/5000		Cost function: 7.718E-05
# Epoch: 4200/5000		Cost function: 2.048E-06
# Epoch: 4250/5000		Cost function: 3.280E-07
# Epoch: 4300/5000		Cost function: 3.198E-07
# Epoch: 4350/5000		Cost function: 3.145E-07
# Epoch: 4400/5000		Cost function: 3.094E-07
# Epoch: 4450/5000		Cost function: 2.469E-04
# Epoch: 4500/5000		Cost function: 1.585E-06
# Epoch: 4550/5000		Cost function: 3.077E-07
# Epoch: 4600/5000		Cost function: 2.986E-07
# Epoch: 4650/5000		Cost function: 2.934E-07
# Epoch: 4700/5000		Cost function: 2.883E-07
# Epoch: 4750/5000		Cost function: 2.884E-07
# Epoch: 4800/5000		Cost function: 5.109E-05
# Epoch: 4850/5000		Cost function: 3.988E-07
# Epoch: 4900/5000		Cost function: 2.795E-07
# Epoch: 4950/5000		Cost function: 2.721E-07

# %% [markdown]
# ## Post-processing

# %%
numberOfTimeSteps = 10000  # for the forward Euler scheme

# %% [markdown]
# forward Euler scheme

# %%
tPrediction = np.linspace(0, tmaxValidation, numberOfTimeSteps + 1)
dt = tmaxValidation / numberOfTimeSteps
xPrediction = torch.zeros((2, numberOfTimeSteps + 1), requires_grad=False)

xPrediction[:, 0] = validationData[0, :2]

for i in range(numberOfTimeSteps):
    xPrediction[:, i + 1] = (xPrediction[:, i] + dt * model(xPrediction[:, i])).detach()

# %% [markdown]
# transient response

# %%
fig, ax = plt.subplots()
ax.plot(tPrediction, xPrediction[0, :], 'k')
ax.plot(tValidation, validationData[:, 0], 'r--')
plt.show()

# %% [markdown]
# position-momentum space

# %%
fig, ax = plt.subplots()
ax.plot(xPrediction[0, :], xPrediction[1, :], 'k')
ax.plot(validationData[:, 0], validationData[:, 1], 'r--')
plt.show()

# %% [markdown]
# energy evolution

# %%
fig, ax = plt.subplots()
ax.plot(tPrediction, 0.5 / m * xPrediction[1, :] ** 2, 'k--')
ax.plot(tPrediction, 0.5 * k * xPrediction[0, :] ** 2, 'k:')
ax.plot(tPrediction, 0.5 / m * xPrediction[1, :] ** 2 + 0.5 * k * xPrediction[0, :] ** 2, 'k')

ax.plot(tValidation, 0.5 / m * validationData[:, 1] ** 2, 'r--')
ax.plot(tValidation, 0.5 * k * validationData[:, 0] ** 2, 'r:')
ax.plot(tValidation, 0.5 / m * validationData[:, 1] ** 2 + 0.5 * k * validationData[:, 0] ** 2, 'r')
plt.show()

# %% [markdown]
# learning history

# %%
fig, ax = plt.subplots()
ax.plot(costHistory, 'k')
ax.set_yscale('log')
plt.show()
